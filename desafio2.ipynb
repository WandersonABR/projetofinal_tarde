# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
CREATE TABLE avaliacao (
    id INT AUTO_INCREMENT PRIMARY KEY,
    nota2 INT,
    nota1 INT,
    nota3 INT,
    nota4 INT,
    fk_aluno_id INT
);

ALTER TABLE avaliacao
ADD CONSTRAINT CHECK (nota1 <= 25),
ADD CONSTRAINT CHECK (nota2 <= 25),
ADD CONSTRAINT CHECK (nota3 <= 25),
ADD CONSTRAINT CHECK (nota4 <= 25);

ALTER TABLE avaliacao ADD CONSTRAINT FK_avaliacao_2
    FOREIGN KEY (fk_aluno_id)
    REFERENCES aluno (id)
    ON DELETE CASCADE;
    
INSERT INTO avaliacao (fk_aluno_id, nota1, nota2, nota3, nota4) VALUES (120, 20, 22, 25, 25);
INSERT INTO avaliacao (fk_aluno_id, nota1, nota2, nota3, nota4) VALUES (121, 22, 20, 23, 24);
INSERT INTO avaliacao (fk_aluno_id, nota1, nota2, nota3, nota4) VALUES (122, 20, 22, 22, 21);
INSERT INTO avaliacao (fk_aluno_id, nota1, nota2, nota3, nota4) VALUES (123, 25, 25, 25, 25);
INSERT INTO avaliacao (fk_aluno_id, nota1, nota2, nota3, nota4) VALUES (124, 20, 22, 20, 25);


SELECT * FROM avaliacao;
