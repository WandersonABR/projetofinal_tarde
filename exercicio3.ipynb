# %%
ALTER TABLE aluno ADD COLUMN nome VARCHAR(255),
ADD COLUMN tempo_de_estudo INT,
ADD COLUMN renda_media_familia DECIMAL(10, 2);

INSERT INTO aluno (ra, nome, tempo_de_estudo, renda_media_familia) VALUES ('00034599', 'Wanderson Rodrigues', 10, 2000);
INSERT INTO aluno (ra, nome, tempo_de_estudo, renda_media_familia) VALUES ('00034600', 'Andre Rodrigues', 11, 10000);
INSERT INTO aluno (ra, nome, tempo_de_estudo, renda_media_familia) VALUES ('00034601', 'Ana Caroline Rodrigues', 120, 500000);

SELECT * FROM aluno;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
